# %%
from nltk import tokenize

# %%
import re

# %%
cite = re.compile('(\[\d+\])')
space = re.compile('\s',re.ASCII)
posess = re.compile("(\'s)")
plural = re.compile('(s )')

# %%
with open('wikipedia-actingcareer.txt','r') as wiki:
    article = wiki.read()
wiki.close()

# %%
import string
punc = string.punctuation
nums = string.digits

# %%
# Tokenize as a sentence
a = tokenize.sent_tokenize(''.join(article))
# Remove citations and replace with nothing
b = [re.sub(cite,'',x) for x in a]
# Remove whitespace characters besides ' ' and 
# replace with just a space (' ')
c = [re.sub(space,' ',y) for y in b]
# Remove "'s" and replace with nothing
d = [re.sub(posess,'',z) for z in c]
# Removing trailing spaces
e = [w.strip() for w in d]
# Join list into a string
f = ''.join(e)
# Tokenize individual words (not sentence)
words = tokenize.word_tokenize(f)

# %%
f
# Out:
# 'Since his film debut with a minor role in Fast Times at Ridgemont High (1982), opposite Judge Reinhold and Sean Penn, Cage has appeared in a wide range of films, both mainstream and offbeat.He auditioned for the role of Dallas Winston in his uncle film The Outsiders, based on S.E.Hinton novel, but lost to Matt Dillon.He was also in Coppola films Rumble Fish and Peggy Sue Got Married.Other Cage roles included appearances in the acclaimed 1987 romantic-comedy film Moonstruck, also starring Cher; the Coen Brothers cult-classic comedy Raising Arizona; David Lynch 1990 film Wild at Heart; a lead role in Martin Scorsese 1999 New York City paramedic drama Bringing Out the Dead; and Ridley Scott 2003 black comedy crime film Matchstick Men, in which he played a con artist with obsessive-compulsive disorder.Cage at the 66th Venice Film Festival in September 2009 Cage has been nominated twice for an Academy Award, winning once for his performance as a suicidal alcoholic in Leaving Las Vegas.His other nomination was for his portrayal of real-life screenwriter Charlie Kaufman and Kaufman fictional twin Donald in Adaptation.Despite these successes, most of his lower-profile films have performed poorly at the box office compared to his mainstream action/adventure roles.The suspense thriller 8mm (1999) is considered a cult film.He took the lead role in the 2001 film Captain Corelli Mandolin and learned to play the mandolin from scratch for the part.He made his directorial debut with 2002 Sonny.In 2005, two films he headlined, Lord of War and The Weather Man, failed to find a significant audience despite nationwide releases and good reviews for his performances.Poor reviews for The Wicker Man resulted in low box office sales.The much criticized Ghost Rider (2007), based on the Marvel Comics character, fared better, earning more than $45 million (the top earner) during its opening weekend and over $208 million worldwide through the weekend ending on March 25, 2007.Also in 2007, he starred in Next, which shared the concept of a glimpse into an alternate timeline with Cage film, The Family Man (2000).Most of Cage movies that have achieved financial success were in the action/adventure genre.In his second-highest-grossing film to date, National Treasure, he plays an eccentric historian who goes on a dangerous adventure to find treasure hidden by the Founding Fathers of the United States.Other action hits include The Rock, in which Cage plays a young FBI chemical weapons expert who infiltrates Alcatraz Island in the hope of neutralizing a terrorist threat, Face/Off, a John Woo film where he plays both a hero and a villain, and World Trade Center, director Oliver Stone film about the September 11 attacks.He had a small but notable role as the Chinese criminal mastermind Dr. Fu Manchu in Rob Zombie fake trailer Werewolf Women of the S.S. from the B-movie double feature Grindhouse.In November 2007, Cage was spotted backstage at a Ring of Honor wrestling show in New York City researching for the lead role for The Wrestler.However, Cage dropped out of production shortly afterward because he felt that he did not have enough time to prepare for the role and director Darren Aronofsky preferred Mickey Rourke for the lead part.Rourke would go on to receive an Academy Award nomination for his performance.In an interview with slashfilm.com, Aronofsky said of Cage decision to leave the film that "Nic was a complete gentleman, and he understood that my heart was with Mickey and he stepped aside.I have so much respect for Nic Cage as an actor and I think it really could have worked with Nic but ... you know, Nic was incredibly supportive of Mickey and he is old friends with Mickey and really wanted to help with this opportunity, so he pulled himself out of the race."   Cage at the 2011 San Diego Comic-Con International In 2008, Cage appeared as Joe, a contract killer who undergoes a change of heart while on a work outing in Bangkok, in the film Bangkok Dangerous ...

# %%
final_words = [w.lower() for w in words if w.lower() not in stopwords and w not in punc]

# %%
#import spacy
#nlp=spacy.load('en_core_web_lg')
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))

# %%
import pandas as pd

# %%
from nltk.probability import FreqDist
fdist = FreqDist(final_words)
pd.DataFrame(fdist.most_common(10))
# Out:
#              0   1
# 0         film  39
# 1         cage  27
# 2      starred   9
# 3         role   8
# 4      reviews   7
# 5  performance   6
# 6     received   6
# 7        films   5
# 8         also   5
# 9         lead   5

# %%
import pandas as pd

# %%
wiki_df = pd.DataFrame(e,columns=['Sentence'])

# %%
wiki_df.head(5)
# Out:
#                                             Sentence
# 0  Since his film debut with a minor role in Fast...
# 1  He auditioned for the role of Dallas Winston i...
# 2             Hinton novel, but lost to Matt Dillon.
# 3  He was also in Coppola films Rumble Fish and P...
# 4  Other Cage roles included appearances in the a...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sentiment_analyzer = SentimentIntensityAnalyzer()

# %%
sent_dict = {}
for sentence in wiki_df.Sentence:
    sent_dict[sentence] = sentiment_analyzer.polarity_scores(sentence)

# %%
s_df = pd.DataFrame(sent_dict)
s_df = s_df.T
s_df
# Out:
#                                                     compound    neg    neu  \
# Since his film debut with a minor role in Fast ...    0.0000  0.000  1.000
#  He auditioned for the role of Dallas Winston i...    0.0000  0.000  1.000
# Hinton novel, but lost to Matt Dillon.               -0.3182  0.307  0.521
#  He was also in Coppola films Rumble Fish and P...    0.0000  0.000  1.000
#   Other Cage roles included appearances in the ...   -0.6249  0.140  0.761
#    Cage at the 66th Venice Film Festival in Sep...    0.6808  0.108  0.649
#  His other nomination was for his portrayal of ...    0.0000  0.000  1.000
#  Despite these successes, most of his lower-pro...   -0.4449  0.128  0.872
# The suspense thriller 8mm (1999) is considered ...    0.1027  0.000  0.851
#  He took the lead role in the 2001 film Captain...    0.3400  0.000  0.902
#  He made his directorial debut with 2002 Sonny.       0.0000  0.000  1.000
# In 2005, two films he headlined, Lord of War an...   -0.5423  0.206  0.659
#  Poor reviews for The Wicker Man resulted in lo...   -0.6369  0.342  0.658
#  The much criticized Ghost Rider (2007), based ...    0.4019  0.104  0.734
#  Also in 2007, he starred in Next, which shared...    0.3400  0.000  0.906
#   Most of Cage movies that have achieved financ...    0.5719  0.000  0.778
# In his second-highest-grossing film to date, Na...    0.7506  0.080  0.622
#  Other action hits include The Rock, in which C...   -0.7096  0.246  0.563
#  He had a small but notable role as the Chinese...   -0.9726  0.437  0.563
#   In November 2007, Cage was spotted backstage ...    0.4939  0.000  0.882
# However, Cage dropped out of production shortly...    0.0000  0.000  1.000
# Rourke would go on to receive an Academy Award ...    0.5423  0.000  0.774
#  In an interview with slashfilm.com, Aronofsky ...   -0.0516  0.037  0.963
# I have so much respect for Nic Cage as an actor...    0.9533  0.000  0.732
# "   Cage at the 2011 San Diego Comic-Con Intern...   -0.8126  0.198  0.802
# The film is shot by the Pang Brothers and has a...    0.0000  0.000  1.000
#  In 2009, Cage starred in the science fiction t...    0.1027  0.000  0.903
# In the film, he plays an MIT professor who exam...    0.2500  0.000  0.909
# Startling predictions found inside the capsule ...   -0.1531  0.083  0.826
#  The film received mainly negative reviews but ...    0.5927  0.109  0.650
# ...                                                      ...    ...    ...
#  He portrayed a corrupt police officer with gam...    0.0000  0.000  1.000
# The film was very well received by critics, hol...    0.1263  0.200  0.582
#  Cage was lauded for his performance, with Mich...    0.4404  0.064  0.805
# " This film reunited Cage with Eva Mendes, who ...    0.8074  0.100  0.480
#  In 2010, Cage starred in the period piece Seas...   -0.1280  0.118  0.777
#   In 2012, Cage reprised his role in Ghost Ride...   -0.4404  0.251  0.656
#  He voiced the character Grug Crood in the anim...    0.0000  0.000  1.000
# The Croods received positive reviews from criti...    0.7003  0.131  0.597
#  In the same year he starred as main character ...   -0.7184  0.112  0.833
# The film has received mixed reviews though Cage...    0.4588  0.000  0.765
#   In 2013 he also starred in Joe, an independen...   -0.2960  0.107  0.823
# In this film Nicolas Cage is a tormented man wh...   -0.4404  0.153  0.764
# The film premiered at the 70th Venice Internati...    0.7506  0.000  0.775
#  It was a box office flop, grossing only $2.36 ...   -0.3182  0.254  0.619
# Cage starred alongside Selma Blair and Anne Win...   -0.2263  0.168  0.687
# It was released in theaters on January 19, 2018...   -0.2263  0.177  0.707
# " Director John Waters appreciated the film, na...    0.8519  0.000  0.712
#    Cage at the 2016 Oldenburger International F...    0.7783  0.000  0.769
#  Nick Allen of RogerEbert.com praised the movie...    0.7096  0.096  0.700
# " On October, Mandy producer Elijah Wood announ...   -0.7184  0.125  0.875
#   Later that year, Cage voiced Superman in the ...    0.0000  0.000  1.000
# To the Movies.                                        0.0000  0.000  1.000
# He had originally been slated to portray Superm...    0.0000  0.000  1.000
#  He also voiced Peter Parker / Spider-Man Noir ...    0.0000  0.000  1.000
# Cage based his character, a dark and monochroma...    0.0000  0.000  1.000
# Robinson.                                             0.0000  0.000  1.000
#   On January 28, 2019, Viktor and Irina Yelchin...    0.8126  0.000  0.739
#  The documentary was directed by Garret Price a...    0.6808  0.000  0.851
# Cage starred as the Narrator of the film, readi...    0.0000  0.000  1.000
#                                                       0.0000  0.000  0.000
#
#                                                       pos
# Since his film debut with a minor role in Fast ...  0.000
#  He auditioned for the role of Dallas Winston i...  0.000
# Hinton novel, but lost to Matt Dillon.              0.172
#  He was also in Coppola films Rumble Fish and P...  0.000
#   Other Cage roles included appearances in the ...  0.099
#    Cage at the 66th Venice Film Festival in Sep...  0.243
#  His other nomination was for his portrayal of ...  0.000
#  Despite these successes, most of his lower-pro...  0.000
# The suspense thriller 8mm (1999) is considered ...  0.149
#  He took the lead role in the 2001 film Captain...  0.098
#  He made his directorial debut with 2002 Sonny.     0.000
# In 2005, two films he headlined, Lord of War an...  0.135
#  Poor reviews for The Wicker Man resulted in lo...  0.000
#  The much criticized Ghost Rider (2007), based ...  0.162
#  Also in 2007, he starred in Next, which shared...  0.094
#   Most of Cage movies that have achieved financ...  0.222
# In his second-highest-grossing film to date, Na...  0.298
#  Other action hits include The Rock, in which C...  0.191
#  He had a small but notable role as the Chinese...  0.000
#   In November 2007, Cage was spotted backstage ...  0.118
# However, Cage dropped out of production shortly...  0.000
# Rourke would go on to receive an Academy Award ...  0.226
#  In an interview with slashfilm.com, Aronofsky ...  0.000
# I have so much respect for Nic Cage as an actor...  0.268
# "   Cage at the 2011 San Diego Comic-Con Intern...  0.000
# The film is shot by the Pang Brothers and has a...  0.000
#  In 2009, Cage starred in the science fiction t...  0.097
# In the film, he plays an MIT professor who exam...  0.091
# Startling predictions found inside the capsule ...  0.092
#  The film received mainly negative reviews but ...  0.241
# ...                                                   ...
#  He portrayed a corrupt police officer with gam...  0.000
# The film was very well received by critics, hol...  0.218
#  Cage was lauded for his performance, with Mich...  0.131
# " This film reunited Cage with Eva Mendes, who ...  0.419
#  In 2010, Cage starred in the period piece Seas...  0.105
#   In 2012, Cage reprised his role in Ghost Ride...  0.093
#  He voiced the character Grug Crood in the anim...  0.000
# The Croods received positive reviews from criti...  0.272
#  In the same year he starred as main character ...  0.055
# The film has received mixed reviews though Cage...  0.235
#   In 2013 he also starred in Joe, an independen...  0.070
# In this film Nicolas Cage is a tormented man wh...  0.084
# The film premiered at the 70th Venice Internati...  0.225
#  It was a box office flop, grossing only $2.36 ...  0.127
# Cage starred alongside Selma Blair and Anne Win...  0.145
# It was released in theaters on January 19, 2018...  0.116
# " Director John Waters appreciated the film, na...  0.288
#    Cage at the 2016 Oldenburger International F...  0.231
#  Nick Allen of RogerEbert.com praised the movie...  0.204
# " On October, Mandy producer Elijah Wood announ...  0.000
#   Later that year, Cage voiced Superman in the ...  0.000
# To the Movies.                                      0.000
# He had originally been slated to portray Superm...  0.000
#  He also voiced Peter Parker / Spider-Man Noir ...  0.000
# Cage based his character, a dark and monochroma...  0.000
# Robinson.                                           0.000
#   On January 28, 2019, Viktor and Irina Yelchin...  0.261
#  The documentary was directed by Garret Price a...  0.149
# Cage starred as the Narrator of the film, readi...  0.000
#                                                     0.000
#
# [61 rows x 4 columns]

# %%
from nltk.collocations import BigramAssocMeasures as bigram

# %%
finder = BigramCollocationFinder.from_words(final_words)

# %%
scored = finder.score_ngrams(bigram.raw_freq)

# %%
sorted(bigram for bigram, score in scored)
# Out:
# [("''", 'cage'),
#  ("''", 'director'),
#  ("''", 'film'),
#  ("''", 'october'),
#  ("'80s-tastic", 'passion'),
#  ('...', 'know'),
#  ('.most', 'cage'),
#  ('11', 'attacks.he'),
#  ('135', 'million.in'),
#  ('14.later', 'year'),
#  ('14th-century', 'knight'),
#  ('15-year-old', 'boy'),
#  ('19', '2018'),
#  ('1930s', 'universe'),
#  ('1982', 'opposite'),
#  ('1987', 'romantic-comedy'),
#  ('1990', 'film'),
#  ('1990s.he', 'also'),
#  ('1991', 'novel'),
#  ('1999', 'considered'),
#  ('1999', 'new'),
#  ('2.36', 'million'),
#  ('2000', '.most'),
#  ('2001', 'film'),
#  ('2002', 'sonny.in'),
#  ('2003', 'black'),
#  ('2005', 'two'),
#  ('2007', 'based'),
#  ('2007', 'cage'),
#  ('2007', 'starred'),
#  ('2007.also', '2007'),
#  ('2008', 'cage'),
#  ('2009', 'cage'),
#  ('2010', 'cage'),
#  ('2011', 'san'),
#  ('2012', 'cage'),
#  ('2013', 'also'),
#  ('2013', 'subsequent'),
#  ('2013', 'toronto'),
#  ('2013.the', 'croods'),
#  ('2016', 'oldenburger'),
#  ('2017', 'toronto'),
#  ('2018', 'cage'),
#  ('2018', 'placing'),
#  ('2018', 'received'),
#  ('2018', 'sundance'),
#  ('2019', 'sundance'),
#  ('2019', 'viktor'),
#  ('208', 'million'),
#  ('25', '2007.also'),
#  ('28', '2019'),
#  ('30', '2013'),
#  ('4', 'million'),
#  ('45', 'million'),
#  ('585', 'million'),
#  ('66th', 'venice'),
#  ('70th', 'venice'),
#  ('87', 'positive'),
#  ('8mm', '1999'),
#  ('``', 'endless'),
#  ('``', 'herzog'),
#  ('``', 'nic'),
#  ('``', 'over-the-top'),
#  ('abrams', 'chris'),
#  ('abusive', 'father.the'),
#  ('academy', 'award'),
#  ('acclaim', 'critics'),
#  ('acclaimed', '1987'),
#  ('acclaimed', 'german'),
#  ('accused', 'causing'),
#  ('achieved', 'financial'),
#  ('action', 'hits'),
#  ('action', 'thriller'),
#  ('action/adventure', 'genre.in'),
#  ('action/adventure', 'roles.the'),
#  ('actor', 'think'),
#  ('actors', 'era'),
#  ('adaptation', 'larry'),
#  ('adaptation.despite', 'successes'),
#  ('addictions.the', 'film'),
#  ('advantage', 'cage'),
#  ('adventure', 'find'),
#  ('afterward', 'felt'),
#  ('aggregator', 'rotten'),
#  ('aggregator', 'website'),
#  ('alaskan', 'serial'),
#  ('alaskan', 'state'),
#  ('alcatraz', 'island'),
#  ('alcohol', 'addictions.the'),
#  ('alcoholic', 'leaving'),
#  ('alex', 'proyas.in'),
#  ('allen', 'rogerebert.com'),
#  ('alongside', 'selma'),
#  ('already', 'come'),
#  ('also', 'coppola'),
#  ('also', 'released'),
#  ('also', 'starred'),
#  ('also', 'starring'),
#  ('also', 'voiced'),
#  ('alternate', 'timeline'),
#  ('alternate', 'version'),
#  ('animated', 'film'),
#  ('anne', 'winters'),
#  ('announced', 'intention'),
#  ('anton', 'writings'),
#  ('anton', 'yelchin'),
#  ('anton', '’'),
#  ('antosha', '2019'),
#  ('appearances', 'acclaimed'),
#  ('appeared', 'joe'),
#  ('appeared', 'wide'),
#  ('appreciated', 'film'),
#  ('apprehend', 'hansen'),
#  ('apprentice', 'played'),
#  ('arizona', 'david'),
#  ('aronofsky', 'preferred'),
#  ('aronofsky', 'said'),
#  ('artifice', 'performance'),
#  ('artist', 'obsessive-compulsive'),
#  ('asian', 'flavor.in'),
#  ('aside.i', 'much'),
#  ('attacks.he', 'small'),
#  ('audience', 'despite'),
#  ('auditioned', 'role'),
#  ('august', '30'),
#  ('award', 'nomination'),
#  ('award', 'winning'),
#  ('b-movie', 'double'),
#  ('backstage', 'ring'),
#  ('bad', 'forgettable'),
#  ('bad', 'lieutenant'),
#  ('bangkok', 'dangerous.the'),
#  ('bangkok', 'film'),
#  ('based', 'character'),
#  ('based', 'crimes'),
#  ('based', 'marvel'),
#  ('based', 's.e.hinton'),
#  ('believe', 'world'),
#  ('best', 'movies'),
#  ('better', 'earning'),
#  ('black', 'comedy'),
#  ('black', 'plague'),
#  ('blair', 'anne'),
#  ('bogart', 'specifically'),
#  ('box', 'office'),
#  ('boy', 'played'),
#  ('brian', 'taylor'),
#  ('bringing', 'dead'),
#  ('brothers', 'cult-classic'),
#  ('brothers', 'distinctly'),
#  ('brown', '1991'),
#  ('budget', '135'),
#  ('budget', 'received'),
#  ('burton', 'canceled'),
#  ('cage', '2011'),
#  ('cage', 'actor'),
#  ('cage', 'appeared'),
#  ('cage', 'composer'),
#  ('cage', 'decision'),
#  ('cage', 'dropped'),
#  ('cage', 'eva'),
#  ('cage', 'film'),
#  ('cage', 'finest'),
#  ('cage', 'given'),
#  ('cage', 'greatness'),
#  ('cage', 'movies'),
#  ('cage', 'nominated'),
#  ('cage', 'performance'),
#  ('cage', 'plays'),
#  ('cage', 'reprised'),
#  ('cage', 'roles'),
#  ('cage', 'seeking'),
#  ('cage', 'spotted'),
#  ('cage', 'starred'),
#  ('cage', 'tormented'),
#  ('cage', 'voiced'),
#  ('cagney', 'edward'),
#  ('call', 'new'),
#  ('campaign', 'nicolas'),
#  ('canceled', 'superman'),
#  ('capsule', 'already'),
#  ('capsule', 'unearthed'),
#  ('captain', 'corelli'),
#  ('causing', 'black'),
#  ('center', 'director'),
#  ('change', 'heart'),
#  ('character', 'dark'),
#  ('character', 'fared'),
#  ('character', 'frozen'),
#  ('character', 'grug'),
#  ('characters', 'takes'),
#  ('charlie', 'kaufman'),
#  ('chemical', 'weapons'),
#  ('cher', 'coen'),
#  ('chicago', 'tribune'),
#  ('chinese', 'criminal'),
#  ('cho', 'martin'),
#  ('chris', 'pine'),
#  ('cited', 'highlight'),
#  ('city', 'paramedic'),
#  ('city', 'researching'),
#  ('close', 'week'),
#  ('clutches.the', 'film'),
#  ('co-produced', 'david'),
#  ('coen', 'brothers'),
#  ('collaborators', 'like'),
#  ('come', 'true'),
#  ('comedy', 'crime'),
#  ('comedy', 'film'),
#  ('comedy', 'raising'),
#  ('comic-con', 'international'),
#  ('comics', 'character'),
#  ('compared', 'mainstream'),
#  ('complete', 'gentleman'),
#  ('composer', 'jóhann'),
#  ('con', 'artist'),
#  ('concept', 'glimpse'),
#  ('considered', 'cult'),
#  ('contains', 'various'),
#  ('contents', 'time'),
#  ('contract', 'killer'),
#  ('coppola', 'films'),
#  ('corelli', 'mandolin'),
#  ('corrupt', 'police'),
#  ('cosmatos', 'style-driven'),
#  ('could', 'worked'),
#  ('crime', 'drama'),
#  ('crime', 'film'),
#  ('crimes', 'real-life'),
#  ('criminal', 'mastermind'),
#  ('critical', 'acclaim'),
#  ('criticized', 'ghost'),
#  ('critics', 'box'),
#  ('critics', 'holding'),
#  ('critics', 'praised'),
#  ('critics', 'review'),
#  ('crood', 'animated'),
#  ('croods', 'received'),
#  ('croods', 'released'),
#  ('cult', 'film.he'),
#  ('cult-classic', 'comedy'),
#  ('dad', 'one'),
#  ('dad', 'premiered'),
#  ('dallas', 'winston'),
#  ('dangerous', 'adventure'),
#  ('dangerous.the', 'film'),
#  ('dark', 'monochromatic'),
#  ('darren', 'aronofsky'),
#  ('date', 'national'),
#  ('david', 'gordon'),
#  ('david', 'lynch'),
#  ('dead', 'ridley'),
#  ('debut', '2002'),
#  ('debut', 'based'),
#  ('debut', 'minor'),
#  ('decision', 'leave'),
#  ('deep', 'artifice'),
#  ('defining', 'performance'),
#  ('depicts', 'alaskan'),
#  ('despite', 'nationwide'),
#  ('destruction.the', 'film'),
#  ('died', 'february'),
#  ('diego', 'comic-con'),
#  ('dillon.he', 'also'),
#  ('directed', 'acclaimed'),
#  ('directed', 'alex'),
#  ('directed', 'co-produced'),
#  ('directed', 'garret'),
#  ('directed', 'written'),
#  ('direction.cage', 'starred'),
#  ('director', 'darren'),
#  ('director', 'john'),
#  ('director', 'oliver'),
#  ('director', 'werner'),
#  ('directorial', 'debut'),
#  ('disorder.cage', '66th'),
#  ('disqualified', 'also'),
#  ('distinctly', 'south-east'),
#  ('documentary', 'directed'),
#  ('documentary', 'son'),
#  ('donald', 'adaptation.despite'),
#  ('double', 'feature'),
#  ('dr.', 'fu'),
#  ('drama', 'bringing'),
#  ('drama', 'film'),
#  ('dropped', 'production'),
#  ('drug', 'alcohol'),
#  ('earner', 'opening'),
#  ('earning', '45'),
#  ('eccentric', 'historian'),
#  ('edward', 'g.robinson.on'),
#  ('elementary', 'school.startling'),
#  ('elijah', 'wood'),
#  ('end', 'close'),
#  ('ending', 'march'),
#  ('endless', 'feral'),
#  ('enough', 'time'),
#  ('era', 'james'),
#  ('escaped', 'hansen'),
#  ('eva', 'mendes'),
#  ('examines', 'contents'),
#  ('expert', 'infiltrates'),
#  ('face/off', 'john'),
#  ('failed', 'find'),
#  ('fake', 'trailer'),
#  ('family', 'man'),
#  ('fared', 'better'),
#  ('fast', 'times'),
#  ('father.the', 'film'),
#  ('fathers', 'united'),
#  ('fbi', 'chemical'),
#  ('feature', 'grindhouse.in'),
#  ('february', 'year'),
#  ('felt', 'enough'),
#  ('feral', 'performances'),
#  ('festival', '2018'),
#  ('festival', 'august'),
#  ('festival', 'september'),
#  ('festival.it', 'box'),
#  ('festival.it', 'released'),
#  ('festival.nick', 'allen'),
#  ('festival.the', 'documentary'),
#  ('fiction', 'thriller'),
#  ('fictional', 'twin'),
#  ('film', '``'),
#  ('film', 'bad'),
#  ('film', 'bangkok'),
#  ('film', 'captain'),
#  ('film', 'croods'),
#  ('film', 'date'),
#  ('film', 'debut'),
#  ('film', 'depicts'),
#  ('film', 'directed'),
#  ('film', 'disqualified'),
#  ('film', 'family'),
#  ('film', 'festival'),
#  ('film', 'festival.it'),
#  ('film', 'festival.nick'),
#  ('film', 'festival.the'),
#  ('film', 'mandy'),
#  ('film', 'matchstick'),
#  ('film', 'mom'),
#  ('film', 'moonstruck'),
#  ('film', 'naming'),
#  ('film', 'nicolas'),
#  ('film', 'outsiders'),
#  ('film', 'plays'),
#  ('film', 'premiered'),
#  ('film', 'reading'),
#  ('film', 'received'),
#  ('film', 'reunited'),
#  ('film', 'september'),
#  ('film', 'shot'),
#  ('film', 'superman'),
#  ('film', 'teen'),
#  ('film', 'well'),
#  ('film', 'wild'),
#  ('film.he', 'took'),
#  ('films', 'headlined'),
#  ('films', 'humphrey'),
#  ('films', 'mainstream'),
#  ('films', 'performed'),
#  ('films', 'rumble'),
#  ('financial', 'success'),
#  ('find', 'significant'),
#  ('find', 'treasure'),
#  ('finest', "''"),
#  ('fish', 'peggy'),
#  ('flavor.in', '2009'),
#  ('flop', 'grossing'),
#  ('forgettable', 'cosmatos'),
#  ('foster', 'john'),
#  ('found', 'ideal'),
#  ('found', 'inside'),
#  ('founding', 'fathers'),
#  ('fourth', 'personal'),
#  ('friends', 'collaborators'),
#  ('friends', 'mickey'),
#  ('frozen', 'ground'),
#  ('fu', 'manchu'),
#  ('full', 'advantage'),
#  ('g.robinson.on', 'january'),
#  ('gambling', 'drug'),
#  ('garret', 'price'),
#  ('genre.in', 'second-highest-grossing'),
#  ('gentleman', 'understood'),
#  ('gentlemen', 'nicolas'),
#  ('german', 'director'),
#  ('ghost', 'rider'),
#  ('ghost', 'rider.in'),
#  ('girl', 'accused'),
#  ('given', 'movies'),
#  ('glimpse', 'alternate'),
#  ('go', 'movies.he'),
#  ('go', 'receive'),
#  ('goes', 'dangerous'),
#  ('going', 'end'),
#  ('good', 'bad'),
#  ('good', 'reviews'),
#  ('gordon', 'green'),
#  ('got', 'married.other'),
#  ('greatness', "''"),
#  ('green', 'adaptation'),
#  ('green', 'direction.cage'),
#  ('grindhouse.in', 'november'),
#  ('grossing', '2.36'),
#  ('grossing', '585'),
#  ('ground', 'thriller'),
#  ('grug', 'crood'),
#  ('hansen', 'clutches.the'),
#  ('hansen', 'film'),
#  ('hansen', 'partnering'),
#  ('headlined', 'lord'),
#  ('heart', 'lead'),
#  ('heart', 'mickey'),
#  ('heart', 'work'),
#  ('help', 'opportunity'),
#  ('hero', 'villain'),
#  ('herzog', 'found'),
#  ('herzog.he', 'portrayed'),
#  ('hidden', 'founding'),
#  ('high', '1982'),
#  ('highlight', 'solid.in'),
#  ('hires', '15-year-old'),
#  ('historian', 'goes'),
#  ('hits', 'include'),
#  ('holding', 'rating'),
#  ('honor', 'wrestling'),
#  ('hope', 'neutralizing'),
#  ('horror', 'comedy'),
#  ('humphrey', 'bogart'),
#  ('ideal', 'interpreter'),
#  ('include', 'rock'),
#  ('included', 'appearances'),
#  ('incredibly', 'supportive'),
#  ('independent', 'crime'),
#  ('infiltrates', 'alcatraz'),
#  ('inside', 'capsule'),
#  ('intention', 'sizing'),
#  ('interest', 'ghost'),
#  ('international', '2008'),
#  ('international', 'film'),
#  ('interpreter', 'performer'),
#  ('interview', 'slashfilm.com'),
#  ('interviews', 'anton'),
#  ('involved', 'destruction.the'),
#  ('irina', 'yelchin'),
#  ('island', 'hope'),
#  ('j.j.', 'abrams'),
#  ('james', 'cagney'),
#  ('january', '19'),
#  ('january', '28'),
#  ('jennifer', 'lawrence'),
#  ('jodie', 'foster'),
#  ('joe', 'contract'),
#  ('joe', 'independent'),
#  ('john', 'cho'),
#  ('john', 'waters'),
#  ('john', 'woo'),
#  ('judge', 'reinhold'),
#  ('jóhann', 'jóhannsson'),
#  ('jóhannsson', 'died'),
#  ('kaufman', 'fictional'),
#  ('kaufman', 'kaufman'),
#  ('killer', 'robert'),
#  ('killer', 'undergoes'),
#  ('knight', 'transporting'),
#  ('know', 'nic'),
#  ('knowing', 'directed'),
#  ('kristen', 'stewart'),
#  ('ladies', 'gentlemen'),
#  ('landau.cage', 'starred'),
#  ('larry', 'brown'),
#  ('las', 'vegas.his'),
#  ('lauded', 'performance'),
#  ('lawrence', 'jodie'),
#  ('lead', 'believe'),
#  ('lead', 'part.rourke'),
#  ('lead', 'role'),
#  ('learned', 'play'),
#  ('leave', 'film'),
#  ('leaving', 'las'),
#  ('lies', 'deep'),
#  ('lieutenant', 'port'),
#  ('like', 'kristen'),
#  ('list.cage', '2016'),
#  ('lives', '1990s.he'),
#  ('lord', 'war'),
#  ('lost', 'matt'),
#  ('love', 'antosha'),
#  ('love', 'interest'),
#  ('low', 'box'),
#  ('lower-profile', 'films'),
#  ('lynch', '1990'),
#  ('made', 'directorial'),
#  ('madness', 'section'),
#  ('main', 'character'),
#  ('mainly', 'negative'),
#  ('mainstream', 'action/adventure'),
#  ('mainstream', 'offbeat.he'),
#  ('man', '2000'),
#  ('man', 'failed'),
#  ('man', 'hires'),
#  ('man', 'resulted'),
#  ('manchu', 'rob'),
#  ('mandolin', 'learned'),
#  ('mandolin', 'scratch'),
#  ('mandy', 'premiered'),
#  ('mandy', 'producer'),
#  ('march', '25'),
#  ('married.other', 'cage'),
#  ('martin', 'landau.cage'),
#  ('martin', 'scorsese'),
#  ('marvel', 'comics'),
#  ('mastermind', 'dr.'),
#  ('matchstick', 'men'),
#  ('matt', 'dillon.he'),
#  ('men', 'played'),
#  ('mendes', 'played'),
#  ('michael', 'phillips'),
#  ('mickey', 'old'),
#  ('mickey', 'really'),
#  ('mickey', 'rourke'),
#  ('mickey', 'stepped'),
#  ('midnight', 'madness'),
#  ('million', '4'),
#  ('million', 'budget'),
#  ('million', 'top'),
#  ('million', 'worldwide'),
#  ('million.in', 'year'),
#  ('minor', 'role'),
#  ('mit', 'professor'),
#  ('mixed', 'reviews'),
#  ('mom', 'dad'),
#  ('monastery', 'sorcerer'),
#  ('monochromatic', 'alternate'),
#  ('moonstruck', 'also'),
#  ('movie', 'writing'),
#  ('movies', '2018'),
#  ('movies', 'achieved'),
#  ('movies', 'good'),
#  ('movies.he', 'originally'),
#  ('much', 'criticized'),
#  ('much', 'respect'),
#  ('name.in', 'film'),
#  ('naming', 'mom'),
#  ('narrator', 'film'),
#  ('national', 'treasure'),
#  ('nationwide', 'releases'),
#  ('negative', 'reviews'),
#  ('neutralizing', 'terrorist'),
#  ('new', 'orleans'),
#  ('new', 'york'),
#  ('next', 'shared'),
#  ('nic', '...'),
#  ('nic', 'cage'),
#  ('nic', 'complete'),
#  ('nic', 'incredibly'),
#  ('nicolas', 'cage'),
#  ('noir', 'spider-man'),
#  ('nominated', 'twice'),
#  ('nomination', 'performance.in'),
#  ('nomination', 'portrayal'),
#  ('notable', 'role'),
#  ('novel', 'lost'),
#  ('novel', 'name.in'),
#  ('november', '2007'),
#  ('obsessive-compulsive', 'disorder.cage'),
#  ('october', 'mandy'),
#  ('offbeat.he', 'auditioned'),
#  ('office', 'compared'),
#  ('office', 'flop'),
#  ('office', 'sales.the'),
#  ('office', 'success'),
#  ('office', 'winner'),
#  ('officer', 'gambling'),
#  ('old', 'friends'),
#  ('oldenburger', 'international'),
#  ('oliver', 'stone'),
#  ('one', 'best'),
#  ('opening', 'weekend'),
#  ('opening', 'weekend.also'),
#  ('opportunity', 'pulled'),
#  ('opposite', 'judge'),
#  ('originally', 'slated'),
#  ('orleans', 'directed'),
#  ('oscar', 'campaign'),
#  ('outing', 'bangkok'),
#  ('outsiders', 'based'),
#  ('over-the-top', "''"),
#  ('pang', 'brothers'),
#  ('paramedic', 'drama'),
#  ('parker', '1930s'),
#  ('parker', 'spider-man'),
#  ('part.he', 'made'),
#  ('part.rourke', 'would'),
#  ('partnering', 'young'),
#  ('passion', 'weird'),
#  ('peggy', 'sue'),
#  ('penn', 'cage'),
#  ('performance', '``'),
#  ('performance', 'cited'),
#  ('performance', 'green'),
#  ('performance', 'ladies'),
#  ('performance', 'michael'),
#  ('performance', 'suicidal'),
#  ('performance.in', 'interview'),
#  ('performances', 'cage'),
#  ('performances.poor', 'reviews'),
#  ('performed', 'poorly'),
#  ('performer', 'whose'),
#  ('period', 'piece'),
#  ('personal', 'top'),
#  ('peter', 'parker'),
#  ('phillips', 'chicago'),
#  ('piece', 'season'),
#  ('pine', 'jennifer'),
#  ('placing', 'fourth'),
#  ('plague', 'monastery'),
#  ('play', 'mandolin'),
#  ('played', 'cage'),
#  ('played', 'con'),
#  ('played', 'love'),
#  ('played', 'sorcerer.in'),
#  ('played', 'tye'),
#  ('playing', '14th-century'),
#  ('plays', 'eccentric'),
#  ('plays', 'hero'),
#  ('plays', 'mit'),
#  ('plays', 'young'),
#  ('police', 'officer'),
#  ('poorly', 'box'),
#  ('port', 'call'),
#  ('portray', 'superman'),
#  ('portrayal', 'real-life'),
#  ('portrayed', 'corrupt'),
#  ('positive', 'reviews'),
#  ('praised', 'cage'),
#  ('praised', 'movie'),
#  ('predictions', 'found'),
#  ('preferred', 'mickey'),
#  ('premiered', '70th'),
#  ('premiered', 'documentary'),
#  ('premiered', 'january'),
#  ('premiered', 'midnight'),
#  ('prepare', 'role'),
#  ('price', 'contains'),
#  ('producer', 'elijah'),
#  ('production', 'shortly'),
#  ('professor', 'examines'),
#  ('protects', 'abusive'),
#  ('proyas.in', 'film'),
#  ('pulled', 'race'),
#  ('race', "''"),
#  ('raising', 'arizona'),
#  ('range', 'films'),
#  ('rating', '87'),
#  ('reading', 'various'),
#  ('real-life', 'alaskan'),
#  ('real-life', 'screenwriter'),
#  ('really', 'could'),
#  ('really', 'wanted'),
#  ('receive', 'academy'),
#  ('received', 'critical'),
#  ('received', 'critics'),
#  ('received', 'mainly'),
#  ('received', 'mixed'),
#  ('received', 'positive'),
#  ('reinhold', 'sean'),
#  ('released', '2013.the'),
#  ('released', 'theaters'),
#  ('released', 'vod'),
#  ('releases', 'good'),
#  ('reprised', 'role'),
#  ('researching', 'lead'),
#  ('respect', 'nic'),
#  ('resulted', 'low'),
#  ('reunited', 'cage'),
#  ('review', 'aggregator'),
#  ('reviews', 'box'),
#  ('reviews', 'critics'),
#  ('reviews', 'performances.poor'),
#  ('reviews', 'review'),
#  ('reviews', 'though'),
#  ('reviews', 'wicker'),
#  ('rider', '2007'),
#  ('rider', 'sequel'),
#  ('rider', 'spirit'),
#  ('rider.in', '2010'),
#  ('ridgemont', 'high'),
#  ('ridley', 'scott'),
#  ('ring', 'honor'),
#  ('rob', 'zombie'),
#  ('robert', 'hansen'),
#  ('rock', 'cage'),
#  ('rogerebert.com', 'praised'),
#  ('role', '2001'),
#  ('role', 'chinese'),
#  ('role', 'dallas'),
#  ('role', 'director'),
#  ('role', 'fast'),
#  ('role', 'ghost'),
#  ('role', 'martin'),
#  ('role', 'wrestler.however'),
#  ('roles', 'included'),
#  ('roles.the', 'suspense'),
#  ('romantic-comedy', 'film'),
#  ('rotten', 'tomatoes'),
#  ('rotten', 'tomatoes.cage'),
#  ('rourke', 'lead'),
#  ('rumble', 'fish'),
#  ('s.e.hinton', 'novel'),
#  ('s.s.', 'b-movie'),
#  ('said', 'cage'),
#  ('sales.the', 'much'),
#  ('san', 'diego'),
#  ('school.startling', 'predictions'),
#  ('science', 'fiction'),
#  ('scorsese', '1999'),
#  ('scott', '2003'),
#  ('scott', 'walker'),
#  ('scratch', 'part.he'),
#  ('screening', '2013'),
#  ('screenwriter', 'charlie'),
#  ('sean', 'penn'),
#  ('season', 'witch'),
#  ('second-highest-grossing', 'film'),
#  ('section', '2017'),
#  ('seeking', 'apprehend'),
#  ('selma', 'blair'),
#  ('september', '11'),
#  ('september', '14.later'),
#  ('september', '2009'),
#  ('sequel', 'ghost'),
#  ('serial', 'killer'),
#  ('shared', 'concept'),
#  ('sheridan', 'protects'),
#  ('shortly', 'afterward'),
#  ('shot', 'pang'),
#  ('show', 'new'),
#  ('significant', 'audience'),
#  ('since', 'film'),
#  ('sizing', 'oscar'),
#  ('slashfilm.com', 'aronofsky'),
#  ('slated', 'portray'),
#  ('small', 'notable'),
#  ('solid.in', '2013'),
#  ('somehow', 'involved'),
#  ('son', 'anton'),
#  ('son', 'elementary'),
#  ('son', 'somehow'),
#  ('sonny.in', '2005'),
#  ('sorcerer', 'apprentice'),
#  ('sorcerer.in', '2012'),
#  ('south-east', 'asian'),
#  ('specifically', 'voices'),
#  ('spider-man', 'noir'),
#  ('spider-man', 'spider-verse.cage'),
#  ('spider-verse.cage', 'based'),
#  ('spirit', 'vengeance.he'),
#  ('spotted', 'backstage'),
#  ('starred', 'action'),
#  ('starred', 'alongside'),
#  ('starred', 'film'),
#  ('starred', 'joe'),
#  ('starred', 'main'),
#  ('starred', 'narrator'),
#  ('starred', 'next'),
#  ('starred', 'period'),
#  ('starred', 'science'),
#  ('starring', 'cher'),
#  ('state', 'trooper'),
#  ('states.other', 'action'),
#  ('stepped', 'aside.i'),
#  ('stewart', 'j.j.'),
#  ('stone', 'film'),
#  ('style-driven', "'80s-tastic"),
#  ('subsequent', 'screening'),
#  ('success', 'action/adventure'),
#  ('success', 'grossing'),
#  ('successes', 'lower-profile'),
#  ('sue', 'got'),
#  ('suicidal', 'alcoholic'),
#  ('sundance', 'film'),
#  ('superman', 'animated'),
#  ('superman', 'film'),
#  ('superman', 'lives'),
#  ('superman', 'tim'),
#  ('supportive', 'mickey'),
#  ('suspense', 'thriller'),
#  ('takes', 'full'),
#  ('taylor', 'horror'),
#  ('teen', 'titans'),
#  ('terrorist', 'threat'),
#  ('theaters', 'january'),
#  ('think', 'really'),
#  ('though', 'cage'),
#  ('threat', 'face/off'),
#  ('thriller', '8mm'),
#  ('thriller', 'crime'),
#  ('thriller', 'film'),
#  ('thriller', 'knowing'),
#  ('tim', 'burton'),
#  ('time', 'capsule'),
#  ('time', 'prepare'),
#  ('timeline', 'cage'),
#  ('times', 'ridgemont'),
#  ('titans', 'go'),
#  ('tomatoes', 'defining'),
#  ('tomatoes.cage', 'lauded'),
#  ('took', 'lead'),
#  ('top', 'earner'),
#  ('top', 'list.cage'),
#  ('tormented', 'man'),
#  ('toronto', 'international'),
#  ('trade', 'center'),
#  ('trailer', 'werewolf'),
#  ('transporting', 'girl'),
#  ('treasure', 'hidden'),
#  ('treasure', 'plays'),
#  ('tribune', 'writing'),
#  ('trooper', 'played'),
#  ('true', 'lead'),
#  ('truth', 'lies'),
#  ('twice', 'academy'),
#  ('twin', 'donald'),
#  ('two', 'films'),
#  ('tye', 'sheridan'),
#  ('uncle', 'film'),
#  ('undergoes', 'change'),
#  ('understood', 'heart'),
#  ('unearthed', 'son'),
#  ('united', 'states.other'),
#  ('universe', 'films'),
#  ('various', 'anton'),
#  ('various', 'interviews'),
#  ('vegas.his', 'nomination'),
#  ('vengeance.he', 'voiced'),
#  ('venice', 'film'),
#  ('venice', 'international'),
#  ('version', 'peter'),
#  ('viktor', 'irina'),
#  ('villain', 'world'),
#  ('vod', 'september'),
#  ('voiced', 'character'),
#  ('voiced', 'peter'),
#  ('voiced', 'superman'),
#  ('voices', 'actors'),
#  ('walker', 'directorial'),
#  ('wanted', 'help'),
#  ('war', 'weather'),
#  ('waters', 'appreciated'),
#  ('weapons', 'expert'),
#  ('weather', 'man'),
#  ('website', 'rotten'),
#  ('week', 'son'),
#  ('weekend', '208'),
#  ('weekend', 'ending'),
#  ('weekend.also', '2009'),
#  ('weird', 'worlds'),
#  ('well', 'received'),
#  ('werewolf', 'women'),
#  ('werner', 'herzog.he'),
#  ('whose', 'truth'),
#  ('wicker', 'man'),
#  ('wide', 'range'),
#  ('wild', 'heart'),
#  ('winner', 'opening'),
#  ('winning', 'performance'),
#  ('winston', 'uncle'),
#  ('winters', 'brian'),
#  ('witch', 'playing'),
#  ('woman', 'escaped'),
#  ('women', 's.s.'),
#  ('woo', 'film'),
#  ('wood', 'announced'),
#  ('work', 'outing'),
#  ('worked', 'nic'),
#  ('world', 'going'),
#  ('world', 'trade'),
#  ('worlds', 'characters'),
#  ('worldwide', 'weekend'),
#  ('would', 'go'),
#  ('wrestler.however', 'cage'),
#  ('wrestling', 'show'),
#  ('writing', '``'),
#  ('written', 'scott'),
#  ('year', 'cage'),
#  ('year', 'film'),
#  ('year', 'starred'),
#  ('yelchin', 'love'),
#  ('yelchin', 'premiered'),
#  ('york', 'city'),
#  ('young', 'fbi'),
#  ('young', 'woman'),
#  ('zombie', 'fake'),
#  ('’', 'friends')]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(s_df.neg, bins=15,color='darkred',edgecolor='black')
# Out:
# (array([32.,  1.,  3.,  7.,  6.,  2.,  3.,  1.,  3.,  0.,  1.,  1.,  0.,
#          0.,  1.]),
#  array([0.        , 0.02913333, 0.05826667, 0.0874    , 0.11653333,
#         0.14566667, 0.1748    , 0.20393333, 0.23306667, 0.2622    ,
#         0.29133333, 0.32046667, 0.3496    , 0.37873333, 0.40786667,
#         0.437     ]),
#  <a list of 15 Patch objects>)

# %%
plt.hist(s_df.neu, bins=15, edgecolor='black',color='gold')
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  0.,  0.,  2.,  4.,  7.,  5., 10.,  8.,
#          7., 17.]),
#  array([0.        , 0.06666667, 0.13333333, 0.2       , 0.26666667,
#         0.33333333, 0.4       , 0.46666667, 0.53333333, 0.6       ,
#         0.66666667, 0.73333333, 0.8       , 0.86666667, 0.93333333,
#         1.        ]),
#  <a list of 15 Patch objects>)

# %%
plt.hist(s_df.pos, bins=15,edgecolor='black', color='darkgreen')
# Out:
# (array([24.,  1.,  1.,  9.,  5.,  4.,  2.,  3.,  6.,  3.,  2.,  0.,  0.,
#          0.,  1.]),
#  array([0.        , 0.02793333, 0.05586667, 0.0838    , 0.11173333,
#         0.13966667, 0.1676    , 0.19553333, 0.22346667, 0.2514    ,
#         0.27933333, 0.30726667, 0.3352    , 0.36313333, 0.39106667,
#         0.419     ]),
#  <a list of 15 Patch objects>)
